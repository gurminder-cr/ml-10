# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df= pd.read_csv('height-weight.csv')
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  23 non-null     int64
#  1   Height  23 non-null     int64
# dtypes: int64(2)
# memory usage: 500.0 bytes

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
df.loc[:,['Weight','Height']]= scaler.fit_transform(df[['Weight','Height']])
# Out:
# /tmp/ipython-input-3945009060.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.64913128 -0.90540541 -1.47750223 -0.79098604 -0.21888922  0.23878824
#   0.3532076   0.92530443  1.21135284  0.23878824  0.46762697  1.21135284
#   1.78344966  1.49740125  0.63925602  0.23878824 -1.36308287 -0.50493763
#   0.12436887  0.75367538 -1.64913128 -1.01982477 -0.10446985]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:,['Weight','Height']]= scaler.fit_transform(df[['Weight','Height']])
# /tmp/ipython-input-3945009060.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-2.01183323 -1.22578288 -1.85462316 -0.7017493   0.08430105  0.18910777
#   0.24151112  0.87035141  1.23717491  0.60833462  0.92275477  1.23717491
#   0.87035141  1.28957827  0.60833462  0.97515812 -0.96376609  0.0318977
#  -0.43973252  0.45112455 -1.54020302 -0.96376609  0.08430105]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:,['Weight','Height']]= scaler.fit_transform(df[['Weight','Height']])

# %%
df.head()
# Out:
#      Weight    Height
# 0 -1.649131 -2.011833
# 1 -0.905405 -1.225783
# 2 -1.477502 -1.854623
# 3 -0.790986 -0.701749
# 4 -0.218889  0.084301

# %%
#independent and dependent variables
x= df[['Height']]
y= df['Weight']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=10)

# %%
x_train
# Out:
#       Height
# 12  0.870351
# 20 -1.540203
# 13  1.289578
# 14  0.608335
# 3  -0.701749
# 21 -0.963766
# 6   0.241511
# 18 -0.439733
# 10  0.922755
# 19  0.451125
# 22  0.084301
# 8   1.237175
# 16 -0.963766
# 17  0.031898
# 0  -2.011833
# 15  0.975158
# 4   0.084301
# 9   0.608335

# %%
y_train
# Out:
# 12    1.783450
# 20   -1.649131
# 13    1.497401
# 14    0.639256
# 3    -0.790986
# 21   -1.019825
# 6     0.353208
# 18    0.124369
# 10    0.467627
# 19    0.753675
# 22   -0.104470
# 8     1.211353
# 16   -1.363083
# 17   -0.504938
# 0    -1.649131
# 15    0.238788
# 4    -0.218889
# 9     0.238788
# Name: Weight, dtype: float64

# %%
model= LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict= model.predict(x_test)

# %%
y_predict
# Out:
# array([ 0.14150042, -1.22985415,  0.80178226, -1.83934508,  1.15731863])

# %%
y_test
# Out:
# 5     0.238788
# 1    -0.905405
# 7     0.925304
# 2    -1.477502
# 11    1.211353
# Name: Weight, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 0.05276791499846166

# %%
r2_score(y_test, y_predict)
# Out:
# 0.9509896540223726
